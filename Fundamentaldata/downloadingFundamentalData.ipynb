# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/downloadingFundamentalData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
symbols=pd.read_html('https://www.moneycontrol.com/financials/reliance/balance-sheetVI/TIS#TIS') # TIS{/2}#TIS

# %%
symbols[0]
# Out:
#                                               0         1  ...        5   6
# 0      Balance Sheet of Tata Steel (in Rs. Cr.)    Mar 21  ...   Mar 17 NaN
# 1                                           NaN   12 mths  ...  12 mths NaN
# 2                      EQUITIES AND LIABILITIES       NaN  ...      NaN NaN
# 3                           SHAREHOLDER'S FUNDS       NaN  ...      NaN NaN
# 4                          Equity Share Capital   1198.78  ...   971.41 NaN
# ..                                          ...       ...  ...      ...  ..
# 61  Non-Current Investments Quoted Market Value    537.85  ...  4422.17 NaN
# 62  Non-Current Investments Unquoted Book Value  27950.42  ...   535.90 NaN
# 63                          CURRENT INVESTMENTS       NaN  ...      NaN NaN
# 64      Current Investments Quoted Market Value        --  ...       -- NaN
# 65      Current Investments Unquoted Book Value   6404.46  ...  5309.81 NaN
#
# [66 rows x 7 columns]

# %%
data=pd.DataFrame([symbols[0][0],symbols[0][1],symbols[0][2],symbols[0][3],symbols[0][4],symbols[0][5]]).T

# %%
data.head(2)
# Out:
#                                           0        1  ...        4        5
# 0  Balance Sheet of Tata Steel (in Rs. Cr.)   Mar 21  ...   Mar 18   Mar 17
# 1                                       NaN  12 mths  ...  12 mths  12 mths
#
# [2 rows x 6 columns]

# %%
data.iloc[0,:].tolist()
# Out:
# ['Balance Sheet of Tata Steel (in Rs. Cr.)',
#  'Mar 21',
#  'Mar 20',
#  'Mar 19',
#  'Mar 18',
#  'Mar 17']

# %%
data.columns=data.iloc[0,:].tolist()

# %%
data.columns
# Out:
# Index(['Balance Sheet of Tata Steel (in Rs. Cr.)', 'Mar 21', 'Mar 20',
#        'Mar 19', 'Mar 18', 'Mar 17'],
#       dtype='object')

# %%
data.tail(5)
# Out:
#        Balance Sheet of Tata Steel (in Rs. Cr.)    Mar 21  ...    Mar 18   Mar 17
# 61  Non-Current Investments Quoted Market Value    537.85  ...    497.21  4422.17
# 62  Non-Current Investments Unquoted Book Value  27950.42  ...   5473.11   535.90
# 63                          CURRENT INVESTMENTS       NaN  ...       NaN      NaN
# 64      Current Investments Quoted Market Value        --  ...        --       --
# 65      Current Investments Unquoted Book Value   6404.46  ...  14640.37  5309.81
#
# [5 rows x 6 columns]

# %%
data.dropna(thresh=3).head(2)
# Out:
#    Balance Sheet of Tata Steel (in Rs. Cr.)   Mar 21  ...   Mar 18   Mar 17
# 0  Balance Sheet of Tata Steel (in Rs. Cr.)   Mar 21  ...   Mar 18   Mar 17
# 1                                       NaN  12 mths  ...  12 mths  12 mths
#
# [2 rows x 6 columns]

# %%
import pandas as pd

# %%
def data_from_moneycontrol(url_string,key=None):
  symbols=pd.read_html(url_string) # TIS{/2}#TIS
  url=url_string+'/2#'+url_string.split('/')[-1]
  symbol_old= pd.read_html(url)
  if key is not None:
    symbol_old[0][0]=key
  data=pd.DataFrame([symbols[0][0],symbols[0][1],symbols[0][2],symbols[0][3],symbols[0][4],symbols[0][5],symbol_old[0][0],symbol_old[0][1],symbol_old[0][2],symbol_old[0][3],symbol_old[0][4],symbol_old[0][5]]).T
  #data=data.drop(1)
  #data=data.drop(13)
  #data=data.drop(23)
  #data=data.drop(31)
  
  
  #data=data.T
  #data=data[1:]
  #d.iloc[0][0]='key_financial'
  
  #data.fillna('void', inplace=True)
  return data

# %%
url1='https://www.moneycontrol.com/financials/statebankofindia/ratiosVI/SBI'
url2='https://www.moneycontrol.com/financials/infosys/profit-lossVI/IT#IT'

# %%
d=data_from_moneycontrol(url1)

# %%
d.head()
# Out:
#                                                    0       1  ...       4       5
# 0  Key Financial Ratios of State Bank of India (i...  Mar 21  ...  Mar 13  Mar 12
# 1                                   Per Share Ratios     NaN  ...     NaN     NaN
# 2                                    Basic EPS (Rs.)   22.87  ...  210.06  184.31
# 3                                  Diluted EPS (Rs.)   22.87  ...  210.06  184.31
# 4                                     Cash EPS (Rs.)   26.59  ...  222.86  189.47
#
# [5 rows x 12 columns]

# %%
d.drop(1)
# Out:
#                                                     0  ...              5
# 0   Key Financial Ratios of State Bank of India (i...  ...         Mar 12
# 2                                     Basic EPS (Rs.)  ...         184.31
# 3                                   Diluted EPS (Rs.)  ...         184.31
# 4                                      Cash EPS (Rs.)  ...         189.47
# 5        Book Value [Excl. Reval Reserve]/Share (Rs.)  ...        1251.05
# 6        Book Value [Incl. Reval Reserve]/Share (Rs.)  ...        1251.05
# 7                                Dividend/Share (Rs.)  ...          35.00
# 8                     Operating Revenue / Share (Rs.)  ...        1587.40
# 9                              Net Profit/Share (Rs.)  ...         174.46
# 10                                Per Employee Ratios  ...            NaN
# 11                    Interest Income/ Employee (Rs.)  ...     4943426.72
# 12                         Net Profit/ Employee (Rs.)  ...      543309.55
# ...

# %%
nifty50=pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1]['Symbol'].tolist()

# %%
nifty50list={'ADANIPORTS.NS':'https://www.moneycontrol.com/financials/adaniportsspecialeconomiczone/ratiosVI/MPS',
 'ASIANPAINT.NS':'https://www.moneycontrol.com/financials/asianpaints/ratiosVI/AP31',
 'AXISBANK.NS':'https://www.moneycontrol.com/financials/axisbank/ratiosVI/AB16',
 'BAJAJ-AUTO.NS':'https://www.moneycontrol.com/financials/bajajauto/ratiosVI/ba10',
 'BAJFINANCE.NS':'https://www.moneycontrol.com/financials/bajajfinance/ratiosVI/BAF',
 'BAJAJFINSV.NS' :'https://www.moneycontrol.com/financials/bajajfinserv/ratiosVI/bf04',
 'BHARTIARTL.NS':'https://www.moneycontrol.com/financials/bhartiairtel/ratiosVI/ba08',
 'BPCL.NS' : 'https://www.moneycontrol.com/financials/bharatpetroleumcorporation/ratiosVI/bpc',
 'BRITANNIA.NS':'https://www.moneycontrol.com/financials/britanniaindustries/ratiosVI/bi',
 'CIPLA.NS':'https://www.moneycontrol.com/financials/cipla/ratiosVI/C',
 'COALINDIA.NS':'https://www.moneycontrol.com/financials/coal%20india/ratiosVI/ci11',
 'DIVISLAB.NS':'https://www.moneycontrol.com/financials/divislaboratories/ratiosVI/dl03',
 'TITAN.NS':'https://www.moneycontrol.com/financials/titancompany/ratiosVI/TI01',
 
 'UPL.NS':'https://www.moneycontrol.com/financials/upl/ratiosVI/UP04',
 'WIPRO.NS':'https://www.moneycontrol.com/financials/wipro/ratiosVI/W'}
 #'ULTRACEMCO.NS': 'https://www.moneycontrol.com/shares/company/financial.com/financials/ultratechcement/ratios/UTC01',

# %%
combined=[]
appended_df=pd.DataFrame()
for key , value in nifty50list.items():
  data=data_from_moneycontrol(nifty50list[key],key)
  print(nifty50list[key])
  combined.append(data)
appended_df=pd.concat(combined, axis=0, ignore_index=True)
# Out:
# https://www.moneycontrol.com/financials/adaniportsspecialeconomiczone/ratiosVI/MPS
# https://www.moneycontrol.com/financials/asianpaints/ratiosVI/AP31
# https://www.moneycontrol.com/financials/axisbank/ratiosVI/AB16
# https://www.moneycontrol.com/financials/bajajauto/ratiosVI/ba10
# https://www.moneycontrol.com/financials/bajajfinance/ratiosVI/BAF
# https://www.moneycontrol.com/financials/bajajfinserv/ratiosVI/bf04
# https://www.moneycontrol.com/financials/bhartiairtel/ratiosVI/ba08
# https://www.moneycontrol.com/financials/bharatpetroleumcorporation/ratiosVI/bpc
# https://www.moneycontrol.com/financials/britanniaindustries/ratiosVI/bi
# https://www.moneycontrol.com/financials/cipla/ratiosVI/C
# https://www.moneycontrol.com/financials/coal%20india/ratiosVI/ci11
# https://www.moneycontrol.com/financials/divislaboratories/ratiosVI/dl03
# https://www.moneycontrol.com/financials/drreddyslaboratories/ratiosVI/DRL
# https://www.moneycontrol.com/financials/eichermotors/ratiosVI/EM
# ...

# %%
appended_df.head(2)
# Out:
#                                                    0       1  ...       4       5
# 0  Key Financial Ratios of Adani Ports and Specia...  Mar 21  ...  Mar 13  Mar 12
# 1                                   Per Share Ratios     NaN  ...     NaN     NaN
#
# [2 rows x 12 columns]

# %%
appended_df.columns=['key stats','mar21','mar20','mar19','mar18','mar17','company','mar16','mar15','mar14','mar13','mar12']

# %%
appended_df.head()
# Out:
#                                            key stats   mar21  ...   mar13   mar12
# 0  Key Financial Ratios of Adani Ports and Specia...  Mar 21  ...  Mar 13  Mar 12
# 1                                   Per Share Ratios     NaN  ...     NaN     NaN
# 2                                    Basic EPS (Rs.)    9.49  ...    8.76    5.88
# 3                                  Diluted EPS (Rs.)    9.49  ...    8.76    5.88
# 4                                     Cash EPS (Rs.)   12.54  ...   10.47    7.24
#
# [5 rows x 12 columns]

# %%
appended_df.to_csv('df.csv')

# %%
data=data_from_moneycontrol(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-539942dfd5ae> in <module>()
# ----> 1 data=data_from_moneycontrol(d)
#
# <ipython-input-12-06c46d3d0497> in data_from_moneycontrol(url_string, key)
#       1 def data_from_moneycontrol(url_string,key=None):
# ----> 2   symbols=pd.read_html(url_string) # TIS{/2}#TIS
#       3   url=url_string+'/2#'+url_string.split('/')[-1]
#       4   symbol_old= pd.read_html(url)
#       5   if key is not None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
data

# %%
data.info()

# %%
pd.read_html('https://www.screener.in/company/RELIANCE/consolidated/#quarters')[0]
