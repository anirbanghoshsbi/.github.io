# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/Getting_Delivery_Volume_Trendlyne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
site='https://trendlyne.com/equity/delivery-analysis/1127/RELIANCE/reliance-industries-ltd/Combined/01-Jul-2021/'

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page)
print(soup.text)
# Out:
#     Delivery percentage and volume analysis - Reliance Industries Ltd. - combined BSE + NSE - 10 May 2021 to 01 Jul 2021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-T4TCDB');
#
# 	/* Google analytics code */
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# ...

# %%
for strong_tag in soup.find_all('Jump in delivery'):
    print(strong_tag.text, strong_tag.next_sibling)
# Out:
#     Delivery percentage and volume analysis - Reliance Industries Ltd. - combined BSE + NSE - 10 May 2021 to 01 Jul 2021
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-T4TCDB');
#
# 	/* Google analytics code */
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# ...

# %%
soup.find_all('p')[17].get_text()
# Out:
# '7.84% upside'

# %%
t=[]
for row in soup.find_all('tr'):
    t.append('\t'.join(row.stripped_strings))

# %%
t[1]
# Out:
# '01 Jul, 2021\t6210.0\t3150.8\t50.7%\t-0.6%\tJump in delivery\t20435.9\t41.9%\t2098.0'

# %%
with open('filetxt.txt' ,'w+') as f:
  for item in t:
    
    
    f.write(item)
    f.write('\n')

# %%
pd.read_csv('/content/filetxt.txt',sep='\t')
# Out:
#             Date  Combined Traded  ...  Rolling Week Delivery % Close Price (NSE)
# 0   01 Jul, 2021           6210.0  ...                      NaN               NaN
# 1   30 Jun, 2021           9546.8  ...                      NaN               NaN
# 2   29 Jun, 2021          12974.6  ...                      NaN               NaN
# 3   28 Jun, 2021          10021.1  ...                      NaN               NaN
# 4   25 Jun, 2021          26381.9  ...                      NaN               NaN
# 5   24 Jun, 2021          43255.1  ...                      NaN               NaN
# 6   23 Jun, 2021           8360.7  ...                      NaN               NaN
# 7   22 Jun, 2021           6211.4  ...                      NaN               NaN
# 8   21 Jun, 2021           5867.8  ...                      NaN               NaN
# 9   18 Jun, 2021          13821.4  ...                      NaN               NaN
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <!--<meta http-equiv="Content-Security-Policy" content="default-src 'self'; image-src https:*; child-src 'none';">-->
#   <meta content="Delivery percentage and volume analysis - Reliance Industries Ltd. - combined BSE + NSE - 10 May 2021 to 01 Jul 2021" name="title"/>
#   <meta content="Reliance Industries Ltd. delivery percentage and volume analysis and insights for the period of 10 May 2021 to 01 Jul 2021 on a combined BSE + NSE data basis" name="description"/>
#   <title>
#    Delivery percentage and volume analysis - Reliance Industries Ltd. - combined BSE + NSE - 10 May 2021 to 01 Jul 2021
#   </title>
#   <link href="//cdnjs.cloudflare.com/" rel="preconnect"/>
#   <link href="//ajax.googleapis.com/" rel="preconnect"/>
# ...

# %%
data = []
table = soup.find('table', attrs={'class':'lineItemsTable'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-1a12d5227837> in <module>()
#       1 data = []
#       2 table = soup.find('table', attrs={'class':'lineItemsTable'})
# ----> 3 table_body = table.find('tbody')
#       4
#       5 rows = table_body.find_all('tr')
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# Out:
# '<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body>\r\n<center><h1>403 Forbidden</h1></center>\r\n<hr><center>nginx/1.16.1</center>\r\n</body>\r\n</html>\r\n'
