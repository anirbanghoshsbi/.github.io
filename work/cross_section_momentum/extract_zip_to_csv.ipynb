# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/cross_section_momentum/extract_zip_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile
import shutil

source_folder = "/content"           # Folder containing ZIP files
levelone_folder = "/content/levelone"

os.makedirs(levelone_folder, exist_ok=True)

def extract_all_zips(source, destination):

    # First copy all zip files to levelone
    for file in os.listdir(source):
        if file.endswith(".zip"):
            shutil.copy(os.path.join(source, file), destination)

    # Now recursively extract inside levelone
    while True:
        zip_found = False

        for root, dirs, files in os.walk(destination):
            for file in files:
                if file.endswith(".zip"):
                    zip_found = True
                    zip_path = os.path.join(root, file)

                    with zipfile.ZipFile(zip_path, 'r') as z:
                        z.extractall(root)

                    os.remove(zip_path)
                    print(f"Extracted and removed: {file}")

        if not zip_found:
            break

    print("All ZIP files fully extracted into levelone.")


extract_all_zips(source_folder, levelone_folder)
# Out:
# Extracted and removed: Reports-Archives-Multiple-07082024.zip
# Extracted and removed: Reports-Archives-Multiple-13092024.zip
# Extracted and removed: Reports-Archives-Multiple-12092024.zip
# Extracted and removed: Reports-Archives-Multiple-19072024.zip
# Extracted and removed: Reports-Archives-Multiple-02092024.zip
# Extracted and removed: Reports-Archives-Multiple-31072024.zip
# Extracted and removed: Reports-Archives-Multiple-06082024.zip
# Extracted and removed: Reports-Archives-Multiple-16082024.zip
# Extracted and removed: Reports-Archives-Multiple-28082024.zip
# Extracted and removed: Reports-Archives-Multiple-22082024.zip
# Extracted and removed: Reports-Archives-Multiple-01082024.zip
# Extracted and removed: Reports-Archives-Multiple-09092024.zip
# Extracted and removed: Reports-Archives-Multiple-25092024.zip
# Extracted and removed: Reports-Archives-Multiple-10092024.zip
# Extracted and removed: Reports-Archives-Multiple-20082024.zip
# Extracted and removed: Reports-Archives-Multiple-03092024.zip
# Extracted and removed: Reports-Archives-Multiple-20092024.zip
# Extracted and removed: Reports-Archives-Multiple-29072024.zip
# Extracted and removed: Reports-Archives-Multiple-09082024.zip
# Extracted and removed: Reports-Archives-Multiple-04092024.zip
# Extracted and removed: Reports-Archives-Multiple-27082024.zip
# Extracted and removed: Reports-Archives-Multiple-16072024.zip
# Extracted and removed: Reports-Archives-Multiple-10072024.zip
# Extracted and removed: Reports-Archives-Multiple-13082024.zip
# Extracted and removed: Reports-Archives-Multiple-19082024.zip
# Extracted and removed: Reports-Archives-Multiple-11072024.zip
# Extracted and removed: Reports-Archives-Multiple-24072024.zip
# Extracted and removed: Reports-Archives-Multiple-23092024.zip
# Extracted and removed: Reports-Archives-Multiple-19092024.zip
# Extracted and removed: Reports-Archives-Multiple-11092024.zip
# Extracted and removed: Reports-Archives-Multiple-23072024.zip
# Extracted and removed: Reports-Archives-Multiple-26092024.zip
# Extracted and removed: Reports-Archives-Multiple-12072024.zip
# Extracted and removed: Reports-Archives-Multiple-23082024.zip
# Extracted and removed: Reports-Archives-Multiple-15072024.zip
# Extracted and removed: Reports-Archives-Multiple-21082024.zip
# Extracted and removed: Reports-Archives-Multiple-22072024.zip
# Extracted and removed: Reports-Archives-Multiple-30082024.zip
# Extracted and removed: Reports-Archives-Multiple-25072024.zip
# Extracted and removed: Reports-Archives-Multiple-30092024.zip
# Extracted and removed: Reports-Archives-Multiple-08082024.zip
# Extracted and removed: Reports-Archives-Multiple-14082024.zip
# Extracted and removed: Reports-Archives-Multiple-05092024.zip
# Extracted and removed: Reports-Archives-Multiple-24092024.zip
# Extracted and removed: Reports-Archives-Multiple-18092024.zip
# Extracted and removed: Reports-Archives-Multiple-06092024.zip
# Extracted and removed: Reports-Archives-Multiple-30072024.zip
# Extracted and removed: Reports-Archives-Multiple-27092024.zip
# Extracted and removed: Reports-Archives-Multiple-12082024.zip
# Extracted and removed: Reports-Archives-Multiple-26072024.zip
# Extracted and removed: Reports-Archives-Multiple-17092024.zip
# Extracted and removed: Reports-Archives-Multiple-29082024.zip
# Extracted and removed: Reports-Archives-Multiple-26082024.zip
# Extracted and removed: Reports-Archives-Multiple-16092024.zip
# Extracted and removed: Reports-Archives-Multiple-02082024.zip
# Extracted and removed: Reports-Archives-Multiple-18072024.zip
# Extracted and removed: Reports-Archives-Multiple-09072024.zip
# Extracted and removed: Reports-Archives-Multiple-05082024.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240916_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240910_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240920_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240909_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240823_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240726_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240812_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240924_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240715_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240906_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240731_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240712_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240805_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240918_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240911_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240919_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240814_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240802_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240725_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240904_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240722_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240913_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240923_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240729_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240813_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240711_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240903_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240723_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240809_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240716_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240822_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240724_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240719_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240806_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240829_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240917_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240807_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240930_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240927_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240826_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240912_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240902_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240830_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240816_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240709_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240819_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240828_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240925_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240718_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240710_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240926_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240827_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240905_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240821_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240820_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240730_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240808_F_0000.csv.zip
# Extracted and removed: BhavCopy_NSE_CM_0_0_0_20240801_F_0000.csv.zip
# All ZIP files fully extracted into levelone.
