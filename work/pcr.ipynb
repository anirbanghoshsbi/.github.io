# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/pcr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/anirbanghoshsbi/data/main/pcr.csv',sep=',')

# %%
data.tail(2)
# Out:
#            Date    PCR   WPCR     Nifty
# 520  2024-04-29  1.417  0.556  22750.55
# 521  2024-04-30  1.393  0.625  22718.30

# %%
data['Date']=pd.to_datetime(data['Date'],format='%Y-%m-%d')

# %%
data=data.set_index('Date')

# %%
fig,ax=plt.subplots(3,1,figsize=(25,10),sharex=True)
ax[0].plot(data['Nifty'], label='Nifty')
ax[1].plot(data['PCR'],color='g',label='Put Call Ratio')
ax[2].plot(data['WPCR'],color='r', label= 'Weighted put call ratio')
ax[0].legend()
ax[1].legend()
ax[2].legend()
plt.show()

# %%
fig,ax=plt.subplots(2,1,figsize=(25,5),sharex=True)
ax[0].plot(data['Nifty'], label='Nifty')
ax[1].plot(data['PCR'].rolling(window=3).mean(),color='g',label='Put Call Ratio 10 EMA')
ax[1].plot(data['WPCR'].rolling(window=10).mean(),color='r', label= 'Weighted put call ratio 10 EMA')
ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
plt.show()

# %%
fig,ax=plt.subplots(2,1,figsize=(25,5),sharex=True)
ax[0].plot(data['Nifty'], label='Nifty')
ax[1].plot(data['PCR'].rolling(window=5).mean()-data['WPCR'].rolling(window=10).mean(),color='g',label='Put Call Ratio 10 EMA')
#ax[1].plot((data['PCR'].rolling(window=3).mean()-data['WPCR'].rolling(window=10).mean()).rolling(window=20).mean(),color='r', label= 'Weighted put call ratio 10 EMA')
ax[1].axhline(y=0, color='b', linestyle='-')
ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
plt.show()
