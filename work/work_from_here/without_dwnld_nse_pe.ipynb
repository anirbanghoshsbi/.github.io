# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/work_from_here/without_dwnld_nse_pe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import date
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/anirbanghoshsbi/data/main/data.csv')

# %%
data.tail(2)
# Out:
#             Date      Open     High       Low    Close     Volume  \
# 3961  2022-12-28  18084.75  18173.1  18068.35  18122.5  193873167
# 3962  2022-12-29  18045.70  18229.7  17992.80  18191.0  281052828
#
#           Turnover    P/E   P/B  Div Yield
# 3961  1.399759e+11  21.78  4.25       1.27
# 3962  1.846605e+11  21.86  4.27       1.27

# %%
data['earnings']=data['Close']/data['P/E']

# %%
plt.plot(data['P/E'])
plt.axhline(y=data['P/E'].median());

# %%
plt.figure(figsize=(8, 6))
plt.plot(data['P/E'][-200:]);

# %%
plt.plot(data['P/E'])
plt.axhline(y=data['P/E'].mean());

# %%
plt.plot(data['earnings'])#-data['earnings'].rolling(window=800).mean())
plt.axhline(y=data['earnings'].median());

# %%
data['Div Yield'].plot()
plt.axhline(y=1.5,color='g');
plt.axhline(y=1.6,color='g');
