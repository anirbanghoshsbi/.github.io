# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/work_from_here/pcr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/anirbanghoshsbi/data/main/pcr.csv',sep=',',parse_dates=[0])

# %%
data.head(2)
# Out:
#         Date    PCR   WPCR     Nifty
# 0 2022-01-03  1.611  0.654  17677.95
# 1 2022-01-04  1.624  0.477  17846.75

# %%
data['Date']=pd.to_datetime(data['Date'],format='%Y %b %d')

# %%
data=data.set_index('Date')

# %%
fig,ax=plt.subplots(3,1,figsize=(25,10),sharex=True)
ax[0].plot(data['Nifty'], label='Nifty')
ax[1].plot(data['PCR'],color='g',label='Put Call Ratio')
ax[2].plot(data['WPCR'],color='r', label= 'Weighted put call ratio')
ax[0].legend()
ax[1].legend()
ax[2].legend()
plt.show()

# %%
fig,ax=plt.subplots(2,1,figsize=(25,10),sharex=True)
ax[0].plot(data['Nifty'], label='Nifty')
ax[1].plot(data['PCR'].rolling(window=5).mean(),color='g',label='Put Call Ratio 5 EMA')
ax[1].plot(data['WPCR'].rolling(window=5).mean(),color='r', label= 'Weighted put call ratio 10 EMA')
ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
plt.show()

# %%
fig,ax=plt.subplots(2,1,figsize=(25,10),sharex=True)
ax[0].plot(data['Nifty'][-200:], label='Nifty')
ax[1].plot(data['WPCR'][-200:],color='r', label= 'Weighted put call ratio')
ax[1].plot(data['WPCR'].rolling(window=20).mean()[-200:],color='g', label= 'Mean 20 days of Weighted put call ratio')
ax[1].axhline(y=4,color='g')
ax[1].axhline(y=3,color='y')
ax[0].legend()
ax[1].legend()
plt.show()

# %%
data.tail(2)
# Out:
#               PCR   WPCR     Nifty
# Date
# 2023-01-23  0.826  0.598  18148.15
# 2023-01-24  0.663  0.684  18128.25
