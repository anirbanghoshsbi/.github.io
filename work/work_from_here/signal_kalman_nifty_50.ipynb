# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/work_from_here/signal_kalman_nifty_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pykalman --q
# !pip install yfinance --q
#!pip install pandas-ta==0.2.45b
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.9/228.9 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pykalman (setup.py) ... done

# %%
#Importing dependencies#
from pykalman import KalmanFilter
import numpy as np
import pylab as pl
import pandas as pd
import yfinance as yf
from scipy import poly1d
from datetime import datetime
#import pandas_ta as ta
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.options.mode.chained_assignment = None

# %%
#ticker = pd.read_csv('https://raw.githubusercontent.com/anirbanghoshsbi/data/main/ind_niftybanklist.csv')

# %%
ticker = pd.read_csv('https://raw.githubusercontent.com/anirbanghoshsbi/data/main/ind_nifty50list.csv')
START = "2013-01-01"

# %%
nifty=yf.download('^nsei',start=START)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ticker
# Out:
#                                     Company Name                  Industry  \
# 0     Adani Ports and Special Economic Zone Ltd.                  SERVICES
# 1                              Asian Paints Ltd.            CONSUMER GOODS
# 2                                 Axis Bank Ltd.        FINANCIAL SERVICES
# 3                                Bajaj Auto Ltd.                AUTOMOBILE
# 4                             Bajaj Finance Ltd.        FINANCIAL SERVICES
# 5                             Bajaj Finserv Ltd.        FINANCIAL SERVICES
# 6              Bharat Petroleum Corporation Ltd.                 OIL & GAS
# 7                             Bharti Airtel Ltd.                   TELECOM
# 8                      Britannia Industries Ltd.            CONSUMER GOODS
# 9                                     Cipla Ltd.                    PHARMA
# 10                               Coal India Ltd.                    METALS
# 11                      Divi's Laboratories Ltd.                    PHARMA
# 12                 Dr. Reddy's Laboratories Ltd.                    PHARMA
# 13                            Eicher Motors Ltd.                AUTOMOBILE
# 14                        Grasim Industries Ltd.  CEMENT & CEMENT PRODUCTS
# 15                         HCL Technologies Ltd.                        IT
# 16                                HDFC Bank Ltd.        FINANCIAL SERVICES
# 17              HDFC Life Insurance Company Ltd.        FINANCIAL SERVICES
# 18                            Hero MotoCorp Ltd.                AUTOMOBILE
# 19                      Hindalco Industries Ltd.                    METALS
# 20                       Hindustan Unilever Ltd.            CONSUMER GOODS
# 21  Housing Development Finance Corporation Ltd.        FINANCIAL SERVICES
# 22                               ICICI Bank Ltd.        FINANCIAL SERVICES
# 23                                      ITC Ltd.            CONSUMER GOODS
# 24                   Indian Oil Corporation Ltd.                 OIL & GAS
# 25                            IndusInd Bank Ltd.        FINANCIAL SERVICES
# 26                                  Infosys Ltd.                        IT
# 27                                JSW Steel Ltd.                    METALS
# 28                      Kotak Mahindra Bank Ltd.        FINANCIAL SERVICES
# 29                          Larsen & Toubro Ltd.              CONSTRUCTION
# 30                      Mahindra & Mahindra Ltd.                AUTOMOBILE
# 31                      Maruti Suzuki India Ltd.                AUTOMOBILE
# 32                                     NTPC Ltd.                     POWER
# 33                             Nestle India Ltd.            CONSUMER GOODS
# 34            Oil & Natural Gas Corporation Ltd.                 OIL & GAS
# 35          Power Grid Corporation of India Ltd.                     POWER
# 36                      Reliance Industries Ltd.                 OIL & GAS
# 37               SBI Life Insurance Company Ltd.        FINANCIAL SERVICES
# 38                             Shree Cement Ltd.  CEMENT & CEMENT PRODUCTS
# 39                           State Bank of India        FINANCIAL SERVICES
# 40            Sun Pharmaceutical Industries Ltd.                    PHARMA
# 41                Tata Consultancy Services Ltd.                        IT
# 42                   Tata Consumer Products Ltd.            CONSUMER GOODS
# 43                              Tata Motors Ltd.                AUTOMOBILE
# 44                               Tata Steel Ltd.                    METALS
# 45                            Tech Mahindra Ltd.                        IT
# 46                            Titan Company Ltd.            CONSUMER GOODS
# 47                                      UPL Ltd.  FERTILISERS & PESTICIDES
# 48                         UltraTech Cement Ltd.  CEMENT & CEMENT PRODUCTS
# 49                                    Wipro Ltd.                        IT
#
#         Symbol Series     ISIN Code
# 0   ADANIPORTS     EQ  INE742F01042
# 1   ASIANPAINT     EQ  INE021A01026
# 2     AXISBANK     EQ  INE238A01034
# 3   BAJAJ-AUTO     EQ  INE917I01010
# 4   BAJFINANCE     EQ  INE296A01024
# 5   BAJAJFINSV     EQ  INE918I01018
# 6         BPCL     EQ  INE029A01011
# 7   BHARTIARTL     EQ  INE397D01024
# 8    BRITANNIA     EQ  INE216A01030
# 9        CIPLA     EQ  INE059A01026
# 10   COALINDIA     EQ  INE522F01014
# 11    DIVISLAB     EQ  INE361B01024
# 12     DRREDDY     EQ  INE089A01023
# 13   EICHERMOT     EQ  INE066A01021
# 14      GRASIM     EQ  INE047A01021
# 15     HCLTECH     EQ  INE860A01027
# 16    HDFCBANK     EQ  INE040A01034
# 17    HDFCLIFE     EQ  INE795G01014
# 18  HEROMOTOCO     EQ  INE158A01026
# 19    HINDALCO     EQ  INE038A01020
# 20  HINDUNILVR     EQ  INE030A01027
# 21        HDFC     EQ  INE001A01036
# 22   ICICIBANK     EQ  INE090A01021
# 23         ITC     EQ  INE154A01025
# 24         IOC     EQ  INE242A01010
# 25  INDUSINDBK     EQ  INE095A01012
# 26        INFY     EQ  INE009A01021
# 27    JSWSTEEL     EQ  INE019A01038
# 28   KOTAKBANK     EQ  INE237A01028
# 29          LT     EQ  INE018A01030
# 30         M&M     EQ  INE101A01026
# 31      MARUTI     EQ  INE585B01010
# 32        NTPC     EQ  INE733E01010
# 33   NESTLEIND     EQ  INE239A01016
# 34        ONGC     EQ  INE213A01029
# 35   POWERGRID     EQ  INE752E01010
# 36    RELIANCE     EQ  INE002A01018
# 37     SBILIFE     EQ  INE123W01016
# 38    SHREECEM     EQ  INE070A01015
# 39        SBIN     EQ  INE062A01020
# 40   SUNPHARMA     EQ  INE044A01036
# 41         TCS     EQ  INE467B01029
# 42  TATACONSUM     EQ  INE192A01025
# 43  TATAMOTORS     EQ  INE155A01022
# 44   TATASTEEL     EQ  INE081A01012
# 45       TECHM     EQ  INE669C01036
# 46       TITAN     EQ  INE280A01028
# 47         UPL     EQ  INE628A01036
# 48  ULTRACEMCO     EQ  INE481G01011
# 49       WIPRO     EQ  INE075A01022

# %%
def find_name(df, column, name_to_search):
    result = df[df[column] == name_to_search].index
    if len(result) > 0:
        return result[0]
    else:
        return None

# %%
searched_name = 'RELIANCE'
index_reliance = find_name(ticker, 'Symbol', searched_name)
searched_name = 'TCS'
index_tcs = find_name(ticker, 'Symbol', searched_name)
searched_name = 'INFY'
index_infy = find_name(ticker, 'Symbol', searched_name)
searched_name = 'HINDUNILVR'
index_hul = find_name(ticker, 'Symbol', searched_name)
searched_name = 'ITC'
index_itc = find_name(ticker, 'Symbol', searched_name)
searched_name = 'HDFCBANK'
index_hdfcbank = find_name(ticker, 'Symbol', searched_name)
searched_name = 'ICICIBANK'
index_icicibank = find_name(ticker, 'Symbol', searched_name)

# %%
index_reliance,index_tcs,index_hdfcbank,index_icicibank
# Out:
# (36, 41, 16, 22)

# %%
lst=[]
for i in range(len(ticker)):
  
  dfi = yf.download(str(ticker.Symbol.iloc[i])+'.ns', start=START)
  df = dfi[['Adj Close']]
  
  f = KalmanFilter(transition_matrices = [1],
                    observation_matrices = [1],
                    initial_state_mean = 0,
                    initial_state_covariance = 1,
                    observation_covariance = 1,
                    transition_covariance = 0.0001)
  mean, cov = f.filter(df['Adj Close'].values)
  mean, std = mean.squeeze(), np.std(cov.squeeze())
  var = 'kalman' 
  df[var]=df['Adj Close'].values - mean
  
  lst.append(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
nlst=[]
for i in range(len(ticker)):
  nlst.append(lst[i].kalman)

# %%
df_kalman = pd.DataFrame(nlst).T

# %%
namelist =[]
for i in range(1,len(ticker)+1):
  namelist.append('kalman_'+str(i))
  
df_kalman.columns = namelist

# %%
def calculate_macd(dataframe):
    column_names = dataframe.columns.tolist()
    macd_dataframes = [dataframe]

    for variable in column_names:
        macd_column = 'macd' + variable
        macd_signal_column = 'macd'+'signal' + variable
        macd_histogram_column = 'hist' + variable
        
        macd = dataframe[variable].ewm(span=26, adjust=False).mean() - dataframe[variable].ewm(span=50, adjust=False).mean()
        macd_signal = macd.ewm(span=18, adjust=False).mean()
        macd_histogram = macd - macd_signal
        
        new_dataframe = pd.DataFrame({macd_column: macd, 
                                      macd_signal_column: macd_signal, 
                                      macd_histogram_column: macd_histogram})
        
        macd_dataframes.append(new_dataframe)
    
    result_dataframe = pd.concat(macd_dataframes, axis=1)
    return result_dataframe

# %%
final_kalman=calculate_macd(df_kalman)

# %%
final_kalman.tail(2)
# Out:
#              kalman_1   kalman_2   kalman_3    kalman_4    kalman_5  \
# Date
# 2023-05-08 -38.551802  51.997814  39.521747  718.670658  317.098857
# 2023-05-09 -32.821913  66.677791  48.830978  691.322874  209.295219
#
#              kalman_6   kalman_7   kalman_8    kalman_9  kalman_10  ...  \
# Date                                                                ...
# 2023-05-08 -32.998421  31.494680  28.900431  518.012559 -55.530811  ...
# 2023-05-09 -28.808985  30.537748  28.464336  509.640607 -49.136954  ...
#
#             histkalman_47  macdkalman_48  macdsignalkalman_48  histkalman_48  \
# Date
# 2023-05-08      16.234741       1.181089             0.361139       0.819950
# 2023-05-09      16.747963       0.002196             0.323355      -0.321159
#
#             macdkalman_49  macdsignalkalman_49  histkalman_49  macdkalman_50  \
# Date
# 2023-05-08      27.433634            36.824745      -9.391110       2.392781
# 2023-05-09      30.676118            36.177521      -5.501403       2.680008
#
#             macdsignalkalman_50  histkalman_50
# Date
# 2023-05-08             0.073363       2.319418
# 2023-05-09             0.347747       2.332261
#
# [2 rows x 200 columns]

# %%
features = final_kalman.columns.tolist()

# %%
feats_set1=[feats for feats in features if feats.startswith('hist')]

# %%
final_dataframe=final_kalman[feats_set1]

# %%
final_dataframe.head(2)
# Out:
#             histkalman_1  histkalman_2  histkalman_3  histkalman_4  \
# Date
# 2013-01-01      0.000000       0.00000      0.000000      0.000000
# 2013-01-02     -0.667007      -2.23272     -1.246593     -7.369047
#
#             histkalman_5  histkalman_6  histkalman_7  histkalman_8  \
# Date
# 2013-01-01      0.000000       0.00000      0.000000      0.000000
# 2013-01-02     -0.692371      -0.47276     -0.323956     -1.477396
#
#             histkalman_9  histkalman_10  ...  histkalman_41  histkalman_42  \
# Date                                     ...
# 2013-01-01      0.000000         0.0000  ...       0.000000        0.00000
# 2013-01-02     -1.082725        -2.0192  ...      -1.785605       -2.66458
#
#             histkalman_43  histkalman_44  histkalman_45  histkalman_46  \
# Date
# 2013-01-01       0.000000        0.00000       0.000000       0.000000
# 2013-01-02      -0.624398       -1.58529      -0.078152      -0.955621
#
#             histkalman_47  histkalman_48  histkalman_49  histkalman_50
# Date
# 2013-01-01       0.000000       0.000000       0.000000       0.000000
# 2013-01-02      -1.387411      -0.417454      -9.899708      -0.726068
#
# [2 rows x 50 columns]

# %%
solution=np.sign(final_dataframe)

# %%
solution['final']=solution.sum(axis=1)

# %%
solution['histkalman_'+str(index_reliance+1)]=solution['histkalman_'+str(index_reliance+1)]*25

# %%
solution['histkalman_'+str(index_hdfcbank+1)]=solution['histkalman_'+str(index_hdfcbank+1)]*10

# %%
solution['histkalman_'+str(index_tcs+1)]=solution['histkalman_'+str(index_tcs+1)]*15

# %%
solution['histkalman_'+str(index_icicibank+1)]=solution['histkalman_'+str(index_icicibank+1)]*10

# %%
solution['histkalman_'+str(index_hul+1)]=solution['histkalman_'+str(index_hul+1)]*12
solution['histkalman_'+str(index_itc+1)]=solution['histkalman_'+str(index_itc+1)]*10

# %%
solution.tail(2)
# Out:
#             histkalman_1  histkalman_2  histkalman_3  histkalman_4  \
# Date
# 2023-05-08           1.0           1.0           1.0           1.0
# 2023-05-09           1.0           1.0           1.0           1.0
#
#             histkalman_5  histkalman_6  histkalman_7  histkalman_8  \
# Date
# 2023-05-08           1.0           1.0           1.0           1.0
# 2023-05-09           1.0           1.0           1.0           1.0
#
#             histkalman_9  histkalman_10  ...  histkalman_42  histkalman_43  \
# Date                                     ...
# 2023-05-08           1.0            1.0  ...           15.0            1.0
# 2023-05-09           1.0            1.0  ...           15.0            1.0
#
#             histkalman_44  histkalman_45  histkalman_46  histkalman_47  \
# Date
# 2023-05-08            1.0            1.0           -1.0            1.0
# 2023-05-09            1.0            1.0           -1.0            1.0
#
#             histkalman_48  histkalman_49  histkalman_50  final
# Date
# 2023-05-08            1.0           -1.0            1.0   38.0
# 2023-05-09           -1.0           -1.0            1.0   36.0
#
# [2 rows x 51 columns]

# %%
solution.final[-100:].plot();

# %%
solution['avg_mov']=solution['final'].rolling(window=10).mean()
nifty['avg_mov']=nifty['Adj Close'].rolling(window=22).mean()

# %%
l=1400

# %%
nifty['spread']=nifty['Close']-nifty['avg_mov']

# %%
nifty=nifty[-l:]
solution=solution[-l:]

# %%
fig, ax = plt.subplots(3,1,figsize=(17,7),sharex=True)
ax[0].plot(nifty.loc[:, :].index, nifty.loc[:, 'Close'],'r', label='Close')
ax[0].plot(nifty.loc[:, :].index, nifty.loc[:, 'avg_mov'],'g', label='mov_avg')
ax[1].plot(solution.loc[:, :].index, solution.loc[:, 'final'],'b', label='Signals')
ax[1].plot(solution.loc[:, :].index, solution.loc[:, 'final'],'r*', label='Signals')
ax[2].plot(nifty.loc[:, :].index,nifty.loc[:,'spread'],'c',label='Spread')
#ax[1].plot(nifty.iloc[:, :].index, nifty.loc[:, 'Close'], label='Nifty')
plt.suptitle('Signals')
ax[0].legend()
ax[1].legend()
ax[1].axhline(y=0)
ax[2].axhline(y=0)
plt.show()

# %%
fig, ax = plt.subplots(2,1,figsize=(17,7),sharex=True)
ax[0].plot(nifty.loc[:, :].index, nifty.loc[:, 'Close'],'r', label='Close')
ax[1].plot(solution.loc[:, :].index, solution.loc[:, 'final'],'b', label='Signals')
#ax[1].plot(solution.iloc[:, :].index, solution.loc[:, 'avg_mov'], label='Moving_Average')
plt.suptitle('Signals')
ax[0].legend()
ax[1].legend()
ax[1].axhline(y=0)
plt.show()

# %%
new=pd.DataFrame()

# %%
new['signal_high'] = np.where((nifty['Close']>nifty['avg_mov']) & (solution['final']>solution['avg_mov']),1,0)

# %%
new['signal_low'] = np.where((nifty['Close']<nifty['avg_mov']) & (solution['final']<solution['avg_mov']),-1,0)

# %%
new['signal_final']=new['signal_high']+new['signal_low']

# %%
#pd.concat([solution.reset_index(),new[-4:]],axis=0)

# %%
l=400

# %%
fig, ax = plt.subplots(3,1,figsize=(17,7),sharex=True)
ax[0].plot(nifty.loc[:, :].index[-l:], nifty.loc[:, 'Close'][-l:],'r', label='Close')
ax[0].plot(nifty.loc[:, :].index[-l:], nifty.loc[:, 'avg_mov'][-l:],'g', label='mov_avg20')
ax[1].plot(solution.loc[:, :].index[-l:], solution.loc[:, 'final'][-l:], label='Signals')
ax[1].plot(solution.loc[:, :].index[-l:], solution.loc[:, 'final'][-l:],'r*', label='Signals')
ax[1].plot(solution.iloc[:, :].index[-l:], solution.loc[:, 'avg_mov'][-l:],'b',label='Moving_average')
ax[2].plot(nifty.loc[:, :].index[-l:],nifty.loc[:,'spread'][-l:],'c',label='Spread')
#ax[3].plot(new.loc[:,:].index[-l:],new.loc[:,'signal_final'][-l:])
plt.suptitle('Signals')
ax[0].legend()
ax[1].legend(loc='upper left')
ax[1].axhline(y=0)
ax[2].axhline(y=0)
ax[1].axhline(y=-40,color='g')
plt.show()

# %%
fig, ax = plt.subplots(2,1,figsize=(10,5),sharex=False)
ax[0].plot(new['signal_final'][-l:])
ax[1].plot(nifty['Close'][-l:].values)
plt.show()

# %%
l=180
fig, ax = plt.subplots(3,1,figsize=(17,7),sharex=True)
ax[0].plot(nifty.loc[:, :].index[-l:], nifty.loc[:, 'Close'][-l:],'r', label='Close')
ax[0].plot(nifty.loc[:, :].index[-l:], nifty.loc[:, 'avg_mov'][-l:],'g', label='Close')
ax[1].plot(solution.loc[:, :].index[-l:], solution.loc[:, 'final'][-l:], label='Signals')
ax[1].plot(solution.loc[:, :].index[-l:], solution.loc[:, 'final'][-l:],'r*', label='Signals')
ax[1].plot(solution.iloc[:, :].index[-l:], solution.loc[:, 'avg_mov'][-l:],'b',label='Moving_average')
ax[2].plot(nifty.loc[:, :].index[-l:],nifty.loc[:,'spread'][-l:],'c',label='Spread')

plt.suptitle('Signals')
ax[0].legend()
ax[1].legend(loc='upper left')
ax[1].axhline(y=0)
ax[2].axhline(y=0)
ax[1].axhline(y=-40,color='g')
plt.show()

# %%
solution['signals']=np.where(solution['final']>0,1,-1)

# %%
print('change in nifty from yesterday' ,(nifty.Close.iloc[-1]-nifty.Close.iloc[-2])/nifty.Close.iloc[-2]*100)
# Out:
# change in nifty from yesterday 0.008480038171934752

# %%
nifty.Close.iloc[-1]
# Out:
# 18265.94921875
