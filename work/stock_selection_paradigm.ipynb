# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/stock_selection_paradigm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pandas_ta --q

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import necessary libraries
import yfinance as yf
import pandas as pd
import numpy as np
import datetime as dt
import pandas_ta as ta
def calculate_tr(high, low, close):
    tr1 = high - low
    tr2 = abs(high - close.shift(1))
    tr3 = abs(low - close.shift(1))
    tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
    return tr

def calculate_dm(high, low):
    up_move = high - high.shift(1)
    down_move = low.shift(1) - low
    plus_dm = up_move.where((up_move > down_move) & (up_move > 0), 0.0)
    minus_dm = down_move.where((down_move > up_move) & (down_move > 0), 0.0)
    return plus_dm, minus_dm

def calculate_adx(high, low, close, period=14):
    tr = calculate_tr(high, low, close)
    plus_dm, minus_dm = calculate_dm(high, low)

    tr_smooth = tr.rolling(window=period).mean()
    plus_dm_smooth = plus_dm.rolling(window=period).mean()
    minus_dm_smooth = minus_dm.rolling(window=period).mean()

    plus_di = 100 * (plus_dm_smooth / tr_smooth)
    minus_di = 100 * (minus_dm_smooth / tr_smooth)

    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.rolling(window=period).mean()

    return adx


# Define the function to evaluate the stock
def evaluate_stock(ticker):
    # Set the time frames
    end_date = dt.datetime.now()
    start_date = end_date - dt.timedelta(days=365)  # 1 year of data

    # Download historical price data
    data = yf.download(ticker, start=start_date, end=end_date)

    # Check if data is available
    if data.empty:
        print(f"No data found for {ticker}.")
        return None

    # Calculate moving averages
    data['50_MA'] = data['Close'].rolling(window=50).mean()
    data['200_MA'] = data['Close'].rolling(window=200).mean()

    # Calculate RSI
    data['RSI'] = ta.rsi(data['Close'], length=14)

    # Calculate MACD
    macd = ta.macd(data['Close'])
    data['MACD'] = macd['MACD_12_26_9']
    data['MACD_Signal'] = macd['MACDs_12_26_9']
    '''
    # Calculate Bollinger Bands
    bollinger = ta.bbands(data['Close'])
    data['BB_upper'] = bollinger['BBU_20_2.0']
    data['BB_lower'] = bollinger['BBL_20_2.0']
    '''
    data['BB_upper'] = data['Close'].rolling(window=20).std() * 2 + data['Close']
    data['BB_lower'] = data['Close'].rolling(window=20).std() * 2 - data['Close']
    # Prepare the criteria dictionary
    criteria = {
        'Ticker': ticker,
        'Weekly Price Increase': False,
        'Monthly Price Increase': False,
        'Quarterly Price Increase': False,
        '50_MA above 200_MA (Golden Cross)': False,
        'Price above 50_MA': False,
        'Price above 200_MA': False,
        'RSI between 50 and 70': False,
        'Avg Volume Week > Month': False,
        'MACD above Signal Line': False,
        'Price above Upper Bollinger Band': False,
        'Higher Highs and Lows': False
    }

    # Evaluate criteria
    # 1. Price Performance
    try:
        weekly_price = data['Close'][-5]
        monthly_price = data['Close'][-21]
        quarterly_price = data['Close'][-63]
        current_price = data['Close'][-1]
    except IndexError:
        print(f"Not enough data for {ticker}.")
        return None

    # Weekly Performance
    if current_price > weekly_price:
        criteria['Weekly Price Increase'] = True

    # Monthly Performance
    if current_price > monthly_price:
        criteria['Monthly Price Increase'] = True

    # Quarterly Performance
    if current_price > quarterly_price:
        criteria['Quarterly Price Increase'] = True

    # 2. Moving Averages
    if data['50_MA'][-1] > data['200_MA'][-1]:
        criteria['50_MA above 200_MA (Golden Cross)'] = True

    if current_price > data['50_MA'][-1]:
        criteria['Price above 50_MA'] = True

    if current_price > data['200_MA'][-1]:
        criteria['Price above 200_MA'] = True

    # 3. RSI
    if data['RSI'][-1] > 50 and data['RSI'][-1] < 70:
        criteria['RSI between 50 and 70'] = True

    # 4. Trading Volume
    avg_volume_week = data['Volume'][-5:].mean()
    avg_volume_month = data['Volume'][-21:].mean()

    if avg_volume_week > avg_volume_month:
        criteria['Avg Volume Week > Month'] = True

    # 5. MACD
    if data['MACD'][-1] > data['MACD_Signal'][-1]:
        criteria['MACD above Signal Line'] = True

    # 6. Bollinger Bands
    if current_price > data['BB_upper'][-1]:
        criteria['Price above Upper Bollinger Band'] = True

    # 7. Higher Highs and Higher Lows
    recent_highs = data['High'][-20:]
    recent_lows = data['Low'][-20:]

    if recent_highs.is_monotonic_increasing and recent_lows.is_monotonic_increasing:
        criteria['Higher Highs and Lows'] = True

    return criteria


# Evaluate each stock and collect results
results = []

# List of stock tickers to evaluate
nifty50_url = "https://raw.githubusercontent.com/anirbanghoshsbi/data/main/ind_nifty50list.csv"
nifty50 = pd.read_csv(nifty50_url)
stock_list = nifty50['Symbol'].apply(lambda x: x + ".NS").tolist()

for stock in stock_list:
    criteria = evaluate_stock(stock)
    if criteria:
        results.append(criteria)

# Convert the results into a pandas DataFrame
df_results = pd.DataFrame(results)

# Set the Ticker as the index
df_results.set_index('Ticker', inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df_results
# Out:
#                Weekly Price Increase  Monthly Price Increase  \
# Ticker
# ADANIENT.NS                    False                    True
# ADANIPORTS.NS                  False                   False
# APOLLOHOSP.NS                  False                   False
# ASIANPAINT.NS                  False                   False
# AXISBANK.NS                    False                   False
# BAJAJ-AUTO.NS                  False                    True
# BAJFINANCE.NS                  False                    True
# BAJAJFINSV.NS                  False                    True
# BPCL.NS                         True                   False
# BHARTIARTL.NS                  False                    True
# BRITANNIA.NS                    True                    True
# CIPLA.NS                        True                    True
# COALINDIA.NS                   False                   False
# DIVISLAB.NS                     True                    True
# DRREDDY.NS                     False                   False
# EICHERMOT.NS                   False                   False
# GRASIM.NS                       True                    True
# HCLTECH.NS                     False                   False
# HDFCBANK.NS                    False                    True
# HDFCLIFE.NS                    False                   False
# HEROMOTOCO.NS                  False                   False
# HINDALCO.NS                     True                    True
# HINDUNILVR.NS                  False                    True
# ICICIBANK.NS                   False                    True
# ITC.NS                         False                    True
# INDUSINDBK.NS                  False                   False
# INFY.NS                        False                   False
# JSWSTEEL.NS                     True                    True
# KOTAKBANK.NS                   False                    True
# LTIM.NS                         True                    True
# LT.NS                          False                   False
# M&M.NS                         False                    True
# MARUTI.NS                      False                    True
# NTPC.NS                         True                    True
# NESTLEIND.NS                   False                    True
# ONGC.NS                        False                   False
# POWERGRID.NS                   False                    True
# RELIANCE.NS                    False                   False
# SBILIFE.NS                     False                   False
# SBIN.NS                        False                   False
# SUNPHARMA.NS                    True                    True
# TCS.NS                         False                   False
# TATACONSUM.NS                  False                   False
# TATAMOTORS.NS                  False                   False
# TATASTEEL.NS                    True                    True
# TECHM.NS                       False                   False
# TITAN.NS                       False                    True
# UPL.NS                          True                   False
# ULTRACEMCO.NS                  False                    True
# WIPRO.NS                       False                    True
#
#                Quarterly Price Increase  50_MA above 200_MA (Golden Cross)  \
# Ticker
# ADANIENT.NS                       False                              False
# ADANIPORTS.NS                     False                               True
# APOLLOHOSP.NS                      True                               True
# ASIANPAINT.NS                      True                               True
# AXISBANK.NS                       False                               True
# BAJAJ-AUTO.NS                      True                               True
# BAJFINANCE.NS                      True                               True
# BAJAJFINSV.NS                      True                               True
# BPCL.NS                            True                               True
# BHARTIARTL.NS                      True                               True
# BRITANNIA.NS                       True                               True
# CIPLA.NS                           True                               True
# COALINDIA.NS                       True                               True
# DIVISLAB.NS                        True                               True
# DRREDDY.NS                         True                               True
# EICHERMOT.NS                       True                               True
# GRASIM.NS                          True                               True
# HCLTECH.NS                         True                               True
# HDFCBANK.NS                       False                               True
# HDFCLIFE.NS                        True                               True
# HEROMOTOCO.NS                      True                               True
# HINDALCO.NS                        True                               True
# HINDUNILVR.NS                      True                               True
# ICICIBANK.NS                       True                               True
# ITC.NS                             True                               True
# INDUSINDBK.NS                     False                              False
# INFY.NS                            True                               True
# JSWSTEEL.NS                        True                               True
# KOTAKBANK.NS                      False                               True
# LTIM.NS                            True                               True
# LT.NS                             False                               True
# M&M.NS                             True                               True
# MARUTI.NS                          True                               True
# NTPC.NS                            True                               True
# NESTLEIND.NS                       True                               True
# ONGC.NS                            True                               True
# POWERGRID.NS                       True                               True
# RELIANCE.NS                       False                               True
# SBILIFE.NS                         True                               True
# SBIN.NS                           False                               True
# SUNPHARMA.NS                       True                               True
# TCS.NS                             True                               True
# TATACONSUM.NS                      True                               True
# TATAMOTORS.NS                     False                               True
# TATASTEEL.NS                      False                               True
# TECHM.NS                           True                               True
# TITAN.NS                           True                               True
# UPL.NS                             True                               True
# ULTRACEMCO.NS                     False                               True
# WIPRO.NS                          False                               True
#
#                Price above 50_MA  Price above 200_MA  RSI between 50 and 70  \
# Ticker
# ADANIENT.NS                 True                True                   True
# ADANIPORTS.NS              False                True                  False
# APOLLOHOSP.NS               True                True                  False
# ASIANPAINT.NS              False                True                  False
# AXISBANK.NS                False                True                  False
# BAJAJ-AUTO.NS               True                True                   True
# BAJFINANCE.NS               True                True                   True
# BAJAJFINSV.NS               True                True                   True
# BPCL.NS                     True                True                   True
# BHARTIARTL.NS               True                True                   True
# BRITANNIA.NS                True                True                   True
# CIPLA.NS                    True                True                   True
# COALINDIA.NS               False                True                  False
# DIVISLAB.NS                 True                True                   True
# DRREDDY.NS                 False                True                   True
# EICHERMOT.NS               False                True                  False
# GRASIM.NS                   True                True                   True
# HCLTECH.NS                  True                True                   True
# HDFCBANK.NS                 True                True                  False
# HDFCLIFE.NS                False                True                  False
# HEROMOTOCO.NS               True                True                  False
# HINDALCO.NS                 True                True                   True
# HINDUNILVR.NS               True                True                   True
# ICICIBANK.NS                True                True                  False
# ITC.NS                      True                True                   True
# INDUSINDBK.NS              False               False                  False
# INFY.NS                     True                True                  False
# JSWSTEEL.NS                 True                True                  False
# KOTAKBANK.NS                True                True                  False
# LTIM.NS                     True                True                   True
# LT.NS                      False               False                  False
# M&M.NS                      True                True                   True
# MARUTI.NS                   True                True                  False
# NTPC.NS                     True                True                   True
# NESTLEIND.NS                True                True                   True
# ONGC.NS                    False                True                  False
# POWERGRID.NS                True                True                   True
# RELIANCE.NS                False               False                  False
# SBILIFE.NS                  True                True                  False
# SBIN.NS                    False                True                  False
# SUNPHARMA.NS                True                True                   True
# TCS.NS                     False                True                  False
# TATACONSUM.NS              False                True                  False
# TATAMOTORS.NS              False               False                  False
# TATASTEEL.NS                True                True                   True
# TECHM.NS                    True                True                  False
# TITAN.NS                    True                True                  False
# UPL.NS                      True                True                   True
# ULTRACEMCO.NS               True                True                   True
# WIPRO.NS                    True                True                  False
#
#                Avg Volume Week > Month  MACD above Signal Line  \
# Ticker
# ADANIENT.NS                       True                    True
# ADANIPORTS.NS                     True                    True
# APOLLOHOSP.NS                     True                   False
# ASIANPAINT.NS                    False                   False
# AXISBANK.NS                       True                   False
# BAJAJ-AUTO.NS                     True                   False
# BAJFINANCE.NS                    False                   False
# BAJAJFINSV.NS                     True                   False
# BPCL.NS                           True                    True
# BHARTIARTL.NS                    False                   False
# BRITANNIA.NS                      True                    True
# CIPLA.NS                          True                   False
# COALINDIA.NS                      True                    True
# DIVISLAB.NS                       True                   False
# DRREDDY.NS                        True                    True
# EICHERMOT.NS                      True                    True
# GRASIM.NS                         True                    True
# HCLTECH.NS                        True                   False
# HDFCBANK.NS                       True                   False
# HDFCLIFE.NS                      False                   False
# HEROMOTOCO.NS                     True                   False
# HINDALCO.NS                       True                    True
# HINDUNILVR.NS                    False                   False
# ICICIBANK.NS                     False                   False
# ITC.NS                            True                   False
# INDUSINDBK.NS                     True                   False
# INFY.NS                           True                   False
# JSWSTEEL.NS                       True                    True
# KOTAKBANK.NS                      True                   False
# LTIM.NS                           True                   False
# LT.NS                             True                   False
# M&M.NS                            True                    True
# MARUTI.NS                         True                    True
# NTPC.NS                           True                    True
# NESTLEIND.NS                     False                    True
# ONGC.NS                           True                    True
# POWERGRID.NS                      True                    True
# RELIANCE.NS                       True                   False
# SBILIFE.NS                        True                   False
# SBIN.NS                           True                    True
# SUNPHARMA.NS                      True                    True
# TCS.NS                            True                   False
# TATACONSUM.NS                    False                   False
# TATAMOTORS.NS                     True                   False
# TATASTEEL.NS                      True                    True
# TECHM.NS                          True                   False
# TITAN.NS                          True                   False
# UPL.NS                           False                   False
# ULTRACEMCO.NS                     True                   False
# WIPRO.NS                         False                   False
#
#                Price above Upper Bollinger Band  Higher Highs and Lows
# Ticker
# ADANIENT.NS                               False                  False
# ADANIPORTS.NS                             False                  False
# APOLLOHOSP.NS                             False                  False
# ASIANPAINT.NS                             False                  False
# AXISBANK.NS                               False                  False
# BAJAJ-AUTO.NS                             False                  False
# BAJFINANCE.NS                             False                  False
# BAJAJFINSV.NS                             False                  False
# BPCL.NS                                   False                  False
# BHARTIARTL.NS                             False                  False
# BRITANNIA.NS                              False                  False
# CIPLA.NS                                  False                  False
# COALINDIA.NS                              False                  False
# DIVISLAB.NS                               False                  False
# DRREDDY.NS                                False                  False
# EICHERMOT.NS                              False                  False
# GRASIM.NS                                 False                  False
# HCLTECH.NS                                False                  False
# HDFCBANK.NS                               False                  False
# HDFCLIFE.NS                               False                  False
# HEROMOTOCO.NS                             False                  False
# HINDALCO.NS                               False                  False
# HINDUNILVR.NS                             False                  False
# ICICIBANK.NS                              False                  False
# ITC.NS                                    False                  False
# INDUSINDBK.NS                             False                  False
# INFY.NS                                   False                  False
# JSWSTEEL.NS                               False                  False
# KOTAKBANK.NS                              False                  False
# LTIM.NS                                   False                  False
# LT.NS                                     False                  False
# M&M.NS                                    False                  False
# MARUTI.NS                                 False                  False
# NTPC.NS                                   False                  False
# NESTLEIND.NS                              False                  False
# ONGC.NS                                   False                  False
# POWERGRID.NS                              False                  False
# RELIANCE.NS                               False                  False
# SBILIFE.NS                                False                  False
# SBIN.NS                                   False                  False
# SUNPHARMA.NS                              False                  False
# TCS.NS                                    False                  False
# TATACONSUM.NS                             False                  False
# TATAMOTORS.NS                             False                  False
# TATASTEEL.NS                              False                  False
# TECHM.NS                                  False                  False
# TITAN.NS                                  False                  False
# UPL.NS                                    False                  False
# ULTRACEMCO.NS                             False                  False
# WIPRO.NS                                  False                  False

# %%
#Replace True with 1 and False with 0
df_numeric = df_results.replace({True: 1, False: 0})

# Sum across the rows
df_numeric['Row_Sum'] = df_numeric.sum(axis=1)
# Out:
#                Weekly Price Increase  Monthly Price Increase  \
# Ticker
# ADANIENT.NS                        0                       1
# ADANIPORTS.NS                      0                       0
# APOLLOHOSP.NS                      0                       0
# ASIANPAINT.NS                      0                       0
# AXISBANK.NS                        0                       0
# BAJAJ-AUTO.NS                      0                       1
# BAJFINANCE.NS                      0                       1
# BAJAJFINSV.NS                      0                       1
# BPCL.NS                            1                       0
# BHARTIARTL.NS                      0                       1
# BRITANNIA.NS                       1                       1
# CIPLA.NS                           1                       1
# COALINDIA.NS                       0                       0
# DIVISLAB.NS                        1                       1
# DRREDDY.NS                         0                       0
# UPL.NS                                        0                      0
# ULTRACEMCO.NS                                 0                      0
# WIPRO.NS                                      0                      0
#
#                Row_Sum
# Ticker
# ADANIENT.NS          6
# ADANIPORTS.NS        4
# APOLLOHOSP.NS        5
# ASIANPAINT.NS        3
# AXISBANK.NS          3
# BAJAJ-AUTO.NS        7
# BAJFINANCE.NS        6
# BAJAJFINSV.NS        7
# BPCL.NS              8
# BHARTIARTL.NS        6
# BRITANNIA.NS         9
# CIPLA.NS             8
# COALINDIA.NS         5
# DIVISLAB.NS          8
# DRREDDY.NS           6
# EICHERMOT.NS         5
# GRASIM.NS            9
# HCLTECH.NS           6
# HDFCBANK.NS          5
# HDFCLIFE.NS          3
# HEROMOTOCO.NS        5
# HINDALCO.NS          9
# HINDUNILVR.NS        6
# ICICIBANK.NS         5
# ITC.NS               7
# INDUSINDBK.NS        1
# INFY.NS              5
# JSWSTEEL.NS          8
# KOTAKBANK.NS         5
# LTIM.NS              8
# LT.NS                2
# M&M.NS               8
# MARUTI.NS            7
# NTPC.NS              9
# NESTLEIND.NS         7
# ONGC.NS              5
# POWERGRID.NS         8
# RELIANCE.NS          2
# SBILIFE.NS           5
# SBIN.NS              4
# SUNPHARMA.NS         9
# TCS.NS               4
# TATACONSUM.NS        3
# TATAMOTORS.NS        2
# TATASTEEL.NS         8
# TECHM.NS             5
# TITAN.NS             6
# UPL.NS               6
# ULTRACEMCO.NS        6
# WIPRO.NS             4

# %%
# Display the updated DataFrame
df_numeric.sort_values(by='Row_Sum', ascending=False)['Row_Sum']
# Out:
# Ticker
# BRITANNIA.NS     9
# NTPC.NS          9
# GRASIM.NS        9
# HINDALCO.NS      9
# SUNPHARMA.NS     9
# BPCL.NS          8
# M&M.NS           8
# CIPLA.NS         8
# TATASTEEL.NS     8
# DIVISLAB.NS      8
# LTIM.NS          8
# JSWSTEEL.NS      8
# POWERGRID.NS     8
# BAJAJ-AUTO.NS    7
# MARUTI.NS        7
# BAJAJFINSV.NS    7
# NESTLEIND.NS     7
# ITC.NS           7
# HINDUNILVR.NS    6
# ADANIENT.NS      6
# TITAN.NS         6
# BHARTIARTL.NS    6
# HCLTECH.NS       6
# ULTRACEMCO.NS    6
# UPL.NS           6
# BAJFINANCE.NS    6
# DRREDDY.NS       6
# HEROMOTOCO.NS    5
# APOLLOHOSP.NS    5
# ONGC.NS          5
# COALINDIA.NS     5
# HDFCBANK.NS      5
# KOTAKBANK.NS     5
# EICHERMOT.NS     5
# INFY.NS          5
# TECHM.NS         5
# ICICIBANK.NS     5
# SBILIFE.NS       5
# TCS.NS           4
# WIPRO.NS         4
# SBIN.NS          4
# ADANIPORTS.NS    4
# TATACONSUM.NS    3
# HDFCLIFE.NS      3
# AXISBANK.NS      3
# ASIANPAINT.NS    3
# RELIANCE.NS      2
# TATAMOTORS.NS    2
# LT.NS            2
# INDUSINDBK.NS    1
# Name: Row_Sum, dtype: int64
