# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/without_dwnld_nse_pe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install nsepy --q

# %%
#from nsepy import get_index_pe_history ,get_history
from datetime import date
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/anirbanghoshsbi/data/main/data.csv')

# %%
data.tail(2)
# Out:
#             Date      Open     High       Low     Close     Volume  \
# 3933  2022-11-18  18382.95  18394.6  18209.80  18307.65  198794846
# 3934  2022-11-21  18246.40  18262.3  18133.35  18159.95       1234
#
#           Turnover    P/E   P/B  Div Yield
# 3933  1.655369e+11  21.79  4.30       1.30
# 3934  3.421000e+03  21.82  4.26       1.35

# %%
data['earnings']=data['Close']/data['P/E']

# %%
plt.plot(data['P/E'])
plt.axhline(y=data['P/E'].median());

# %%
plt.plot(data['P/E']-data['P/E'].rolling(window=400).mean())
plt.axhline(y=0);

# %%
plt.plot(data['earnings'])#-data['earnings'].rolling(window=800).mean())
plt.axhline(y=data['earnings'].median());

# %%
plt.plot(data['Close']-data['Close'].rolling(window=800).mean())
plt.axhline(y=0);

# %%
data['Div Yield'].plot()
plt.axhline(y=1.5,color='g');
plt.axhline(y=1.6,color='g');
