# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/rolling_coor_vixnifty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance --q

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

import datetime
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %%
data = pd.read_csv('/content/vix.csv')

# %%
data['date']=data.time.apply(lambda d: datetime.datetime.fromtimestamp(int(d)).strftime('%d-%m-%Y'))

# %%
del data['time']

# %%
data= data.set_index('date')

# %%
data=data['10-02-2017':]

# %%
data_subset = data[['close','INDIAVIX, NSE: Close']]

# %%
data_subset.columns=['close','close1']

# %%
data_subset['corr_running']=data_subset['close'].rolling(window=14).corr(data_subset['close1']).fillna(0.01)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,1, figsize=(10,5),sharex=True)
ax[0].plot(data_subset['corr_running'][-800:])
ax[1].plot(data_subset['close'][-800:])
ax[0].axhline(y=0.5)
plt.show()
