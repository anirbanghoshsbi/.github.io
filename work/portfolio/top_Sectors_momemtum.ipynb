# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/work/portfolio/top_Sectors_momemtum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Get the list of files in the /content/ directory
files = os.listdir("/content/")

# Filter for CSV files
csv_files = [file for file in files if file.endswith(".csv")]

# Print the names of CSV files
for csv_file in csv_files:
    print(csv_file)
# Out:
# capital goods.csv
# cpse.csv
# privatebanks.csv
# informationtech.csv
# consumerdiscretionary.csv
# bankex.csv
# IPO.csv
# TECk.csv
# consumerdurables.csv
# carbonex.csv
# utilities.csv
# quality.csv
# finanacialservices.csv
# industrial.csv
# power.csv
# metal.csv
# telecom.csv
# energy.csv
# smeipo.csv
# greenex.csv
# reit.csv
# oilandgas.csv
# healthcare.csv
# housing.csv
# manufacturing.csv
# realty.csv
# fmcg.csv
# PSU.csv
# services.csv
# commodities.csv
# Auto.csv
# infrastructure.csv
# momentum.csv

# %%
import pandas as pd
import numpy as np


# Function to calculate returns
def calculate_returns(df):
    df['Monthly Return'] = df['Close'].pct_change(periods=21)
    df['Quarterly Return'] = df['Close'].pct_change(periods=63)
    df['Half-Yearly Return'] = df['Close'].pct_change(periods=126)
    df['Annual Return'] = df['Close'].pct_change(periods=262)
    return df

# Create a list to store dataframes
dataframes = []

# Read each CSV file into a separate dataframe
for item in csv_files:
    df = pd.read_csv(item)
    df.reset_index(inplace=True)
    print(item)

    df.columns = ['Date', 'Open', 'High', 'Low', 'Close','dummy']  # Add column headers
    df['Date'] = pd.to_datetime(df['Date'])  # Now convert the "Date" column to dates
    df['dummy'] = item  # Ensure date format

    df = calculate_returns(df)
    dataframes.append(df)

# %%
# Create a composite score
for df in dataframes:
    df['Composite Score'] = (df['Monthly Return'].iloc[-1] + df['Quarterly Return'].iloc[-1] +
                              df['Half-Yearly Return'].iloc[-1] + df['Annual Return'].iloc[-1]) / 4
    print(df.tail(2))
# Rank dataframes based on composite score
ranked_dataframes = sorted(dataframes, key=lambda x: x['Composite Score'].iloc[-1], reverse=True)

# Access ranked dataframes
for i, df in enumerate(ranked_dataframes):
    print(f"Rank {i+1}: Dataframe from file_{df.iloc[0, 5]}")  # Assuming first column has file name
# Out:
#            Date      Open      High       Low     Close              dummy  \
# 2485 2024-03-20  56457.76  56648.41  55758.53  56480.48  capital goods.csv
# 2486 2024-03-21  56847.46  58130.39  56846.74  58046.00  capital goods.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2485        0.012799          0.031820            0.200546       0.670649
# 2486        0.053883          0.091254            0.232520       0.714157
#
#       Composite Score
# 2485         0.272953
# 2486         0.272953
#            Date     Open     High      Low    Close     dummy  Monthly Return  \
# 2339 2024-03-21  3347.51  3418.94  3346.79  3414.16  cpse.csv       -0.038633
# 2340 2024-03-22  3417.59  3454.92  3384.79  3429.13  cpse.csv       -0.045757
#
#       Quarterly Return  Half-Yearly Return  Annual Return  Composite Score
# 2339          0.187745            0.468930       0.994241          0.40679
# 2340          0.182618            0.494578       0.995722          0.40679
#            Date      Open      High       Low     Close             dummy  \
# 1378 2024-03-20  16653.44  16702.77  16440.59  16570.22  privatebanks.csv
# 1379 2024-03-21  16701.09  16816.57  16667.67  16724.56  privatebanks.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 1378       -0.022451         -0.073390           -0.042509       0.095034
# 1379       -0.006470         -0.055975           -0.025185       0.103574
#
#       Composite Score
# 1378         0.003986
# 1379         0.003986
#            Date      Open      High       Low     Close                dummy  \
# 2487 2024-03-21  36495.08  36777.12  36317.05  36554.34  informationtech.csv
# 2488 2024-03-22  35853.79  36028.88  35350.81  35824.73  informationtech.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.037799          0.029271            0.105954       0.226472
# 2488       -0.073954         -0.010417            0.084681       0.217119
#
#       Composite Score
# 2487         0.054357
# 2488         0.054357
#            Date     Open     High      Low    Close  \
# 2484 2024-03-20  8227.63  8267.97  8138.82  8224.46
# 2485 2024-03-21  8293.20  8372.26  8290.25  8361.70
#
#                           dummy  Monthly Return  Quarterly Return  \
# 2484  consumerdiscretionary.csv       -0.031915          0.052212
# 2485  consumerdiscretionary.csv       -0.010303          0.097803
#
#       Half-Yearly Return  Annual Return  Composite Score
# 2484            0.160177       0.517635         0.199753
# 2485            0.177074       0.534437         0.199753
#            Date      Open      High       Low     Close       dummy  \
# 2485 2024-03-20  52654.98  52989.89  52082.46  52595.65  bankex.csv
# 2486 2024-03-21  52958.51  53340.65  52826.22  52953.45  bankex.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2485       -0.015825          -0.02750            0.014480       0.150768
# 2486       -0.007870          -0.01127            0.026004       0.161036
#
#       Composite Score
# 2485         0.041975
# 2486         0.041975
#            Date      Open      High       Low    Close    dummy  \
# 2485 2024-03-20  12507.44  12539.89  12290.68  12454.5  IPO.csv
# 2486 2024-03-21  12568.76  12700.69  12568.76  12684.5  IPO.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2485       -0.112425         -0.014762            0.158107       0.585777
# 2486       -0.085142          0.044563            0.187802       0.595502
#
#       Composite Score
# 2485         0.185681
# 2486         0.185681
#            Date      Open      High       Low     Close     dummy  \
# 2487 2024-03-21  16507.73  16591.56  16384.37  16449.61  TECk.csv
# 2488 2024-03-22  16193.07  16285.07  16012.52  16207.21  TECk.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.022259          0.053955            0.110306       0.217017
# 2488       -0.051733          0.020605            0.093287       0.215276
#
#       Composite Score
# 2487         0.069359
# 2488         0.069359
#            Date     Open      High       Low     Close                 dummy  \
# 2485 2024-03-20  50225.0  50225.00  49373.34  49863.90  consumerdurables.csv
# 2486 2024-03-21  50164.1  50631.89  50099.31  50558.32  consumerdurables.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2485       -0.025734          0.016536            0.077804       0.331845
# 2486       -0.007752          0.046526            0.082045       0.349646
#
#       Composite Score
# 2485         0.117616
# 2486         0.117616
#            Date     Open     High      Low    Close         dummy  \
# 2485 2024-03-20  3687.03  3699.03  3660.25  3686.26  carbonex.csv
# 2486 2024-03-21  3711.23  3731.15  3708.61  3724.41  carbonex.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2485       -0.019958          0.024163            0.097506       0.283821
# 2486       -0.002977          0.051998            0.111814       0.302442
#
#       Composite Score
# 2485         0.115819
# 2486         0.115819
#            Date     Open     High      Low    Close          dummy  \
# 2484 2024-03-20  5191.18  5219.88  5098.09  5186.50  utilities.csv
# 2485 2024-03-21  5245.18  5333.08  5245.18  5326.37  utilities.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2484       -0.066358           0.08928            0.409145       1.038470
# 2485       -0.020587           0.17323            0.430993       1.076404
#
#       Composite Score
# 2484          0.41501
# 2485          0.41501
#            Date     Open     High      Low    Close        dummy  \
# 2050 2024-03-21  1641.60  1663.00  1641.60  1660.45  quality.csv
# 2051 2024-03-22  1656.17  1669.13  1649.46  1665.79  quality.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2050        -0.00363          0.107351            0.227571       0.429919
# 2051        -0.01570          0.095828            0.237576       0.439389
#
#       Composite Score
# 2050         0.189273
# 2051         0.189273
#            Date      Open      High       Low     Close  \
# 2484 2024-03-20  10098.71  10121.17   9963.83  10051.10
# 2485 2024-03-21  10131.16  10208.32  10131.14  10161.12
#
#                        dummy  Monthly Return  Quarterly Return  \
# 2484  finanacialservices.csv       -0.029853         -0.037683
# 2485  finanacialservices.csv       -0.013485         -0.011518
#
#       Half-Yearly Return  Annual Return  Composite Score
# 2484            0.014467       0.192763         0.052607
# 2485            0.030228       0.205202         0.052607
#            Date      Open      High       Low     Close           dummy  \
# 2486 2024-03-21  11879.74  12123.86  11879.74  12112.30  industrial.csv
# 2487 2024-03-22  12092.89  12289.77  12086.22  12253.42  industrial.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2486        0.019985          0.074524            0.210665       0.726520
# 2487        0.016596          0.074797            0.232998       0.749351
#
#       Composite Score
# 2486         0.268436
# 2487         0.268436
#            Date     Open     High      Low    Close      dummy  \
# 2485 2024-03-20  6297.55  6332.54  6195.81  6316.50  power.csv
# 2486 2024-03-21  6381.03  6519.34  6381.03  6509.54  power.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2485       -0.047218          0.089067            0.366066       0.933461
# 2486       -0.001540          0.173148            0.395606       0.974778
#
#       Composite Score
# 2485         0.385498
# 2486         0.385498
#            Date      Open      High       Low     Close      dummy  \
# 2487 2024-03-21  27258.46  27688.84  27228.14  27638.11  metal.csv
# 2488 2024-03-22  27600.30  27995.74  27390.71  27839.38  metal.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487        0.018784          0.086061            0.202657       0.418707
# 2488        0.012827          0.073391            0.220374       0.431519
#
#       Composite Score
# 2487         0.184528
# 2488         0.184528
#            Date     Open     High      Low    Close        dummy  \
# 2486 2024-03-21  2435.97  2442.23  2408.94  2414.36  telecom.csv
# 2487 2024-03-22  2421.18  2480.14  2415.84  2469.32  telecom.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2486       -0.002277          0.127879            0.173204       0.535140
# 2487        0.006604          0.142659            0.207208       0.578294
#
#       Composite Score
# 2486         0.233691
# 2487         0.233691
#            Date      Open      High       Low     Close       dummy  \
# 2484 2024-03-20  11481.63  11589.67  11407.53  11579.31  energy.csv
# 2485 2024-03-21  11658.02  11770.41  11658.02  11745.85  energy.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2484       -0.070593          0.180204            0.357594       0.563295
# 2485       -0.041987          0.223877            0.377584       0.607552
#
#       Composite Score
# 2484         0.291756
# 2485         0.291756
#            Date      Open      High       Low     Close       dummy  \
# 2487 2024-03-21  52978.08  53774.99  52832.15  53505.88  smeipo.csv
# 2488 2024-03-22  53643.37  54176.59  53046.69  53910.48  smeipo.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.101875          0.185238            0.460703       1.182530
# 2488       -0.107203          0.189284            0.491669       1.197044
#
#       Composite Score
# 2487         0.442698
# 2488         0.442698
#            Date     Open     High      Low    Close        dummy  \
# 2487 2024-03-21  6341.10  6386.06  6338.73  6376.50  greenex.csv
# 2488 2024-03-22  6363.03  6459.08  6341.42  6439.15  greenex.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487        0.004232          0.125514            0.199291       0.470666
# 2488        0.001649          0.128104            0.220109       0.490951
#
#       Composite Score
# 2487         0.210203
# 2488         0.210203
#           Date  Open  High  Low   Close     dummy  Monthly Return  \
# 112 2024-03-20   NaN   NaN  NaN  126.87  reit.csv       -0.000866
# 113 2024-03-21   NaN   NaN  NaN  127.93  reit.csv        0.020501
#
#      Quarterly Return  Half-Yearly Return  Annual Return  Composite Score
# 112          0.043768                 NaN            NaN              NaN
# 113          0.060867                 NaN            NaN              NaN
#            Date      Open      High       Low     Close          dummy  \
# 2487 2024-03-21  26920.74  27196.17  26918.44  27102.01  oilandgas.csv
# 2488 2024-03-22  27178.46  27351.05  26962.64  27164.81  oilandgas.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.051537          0.216280            0.415460       0.587423
# 2488       -0.049952          0.208088            0.422979       0.586905
#
#       Composite Score
# 2487         0.292005
# 2488         0.292005
#            Date      Open      High       Low     Close           dummy  \
# 2487 2024-03-21  34001.29  34135.86  33793.19  34089.09  healthcare.csv
# 2488 2024-03-22  34100.85  34553.20  34090.29  34489.20  healthcare.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.042427          0.122439            0.202442       0.572215
# 2488       -0.034329          0.121648            0.226042       0.591628
#
#       Composite Score
# 2487         0.226247
# 2488         0.226247
#           Date  Open  High  Low    Close        dummy  Monthly Return  \
# 429 2024-03-20   NaN   NaN  NaN  2900.61  housing.csv       -0.043461
# 430 2024-03-21   NaN   NaN  NaN  2960.93  housing.csv       -0.027501
#
#      Quarterly Return  Half-Yearly Return  Annual Return  Composite Score
# 429         -0.006116            0.102139       0.430634         0.146527
# 430          0.037045            0.133353       0.443209         0.146527
#            Date    Open    High     Low   Close              dummy  \
# 2166 2024-03-20  952.25  955.99  946.70  954.95  manufacturing.csv
# 2167 2024-03-21  960.99  968.64  960.32  966.88  manufacturing.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2166       -0.018894          0.070932            0.177845       0.422856
# 2167        0.001450          0.102322            0.188602       0.453146
#
#       Composite Score
# 2166          0.18638
# 2167          0.18638
#            Date     Open     High      Low    Close       dummy  \
# 2487 2024-03-21  6699.97  6796.28  6634.88  6782.89  realty.csv
# 2488 2024-03-22  6818.97  6925.83  6790.53  6906.32  realty.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.050400          0.153535            0.481621       1.128907
# 2488       -0.039178          0.145604            0.526296       1.123323
#
#       Composite Score
# 2487         0.439011
# 2488         0.439011
#            Date      Open      High       Low     Close     dummy  \
# 2487 2024-03-21  19089.38  19157.77  18998.55  19127.73  fmcg.csv
# 2488 2024-03-22  19130.42  19317.26  19121.85  19292.61  fmcg.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.015979         -0.030065            0.017252       0.179014
# 2488       -0.016832         -0.027486            0.032021       0.194385
#
#       Composite Score
# 2487         0.045522
# 2488         0.045522
#            Date      Open      High       Low     Close    dummy  \
# 2487 2024-03-21  17598.47  17915.37  17595.82  17889.81  PSU.csv
# 2488 2024-03-22  17888.00  18100.96  17773.01  17990.44  PSU.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487       -0.040001          0.187378            0.428465       0.876582
# 2488       -0.042130          0.190905            0.457386       0.884070
#
#       Composite Score
# 2487         0.372558
# 2488         0.372558
#           Date     Open     High      Low    Close         dummy  \
# 372 2024-03-20  1305.61  1307.39  1285.86  1299.90  services.csv
# 373 2024-03-21  1316.66  1327.85  1314.28  1325.76  services.csv
#
#      Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 372       -0.068593          0.064576            0.252240       0.666154
# 373       -0.038022          0.133380            0.286646       0.675547
#
#      Composite Score
# 372         0.264388
# 373         0.264388
#            Date     Open     High      Low    Close            dummy  \
# 2484 2024-03-20  6424.40  6431.58  6297.81  6353.73  commodities.csv
# 2485 2024-03-21  6412.58  6486.38  6412.58  6479.82  commodities.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2484       -0.040732         -0.016934            0.066581       0.308305
# 2485       -0.020521          0.039059            0.098336       0.333549
#
#       Composite Score
# 2484         0.112606
# 2485         0.112606
#            Date      Open      High       Low     Close     dummy  \
# 2487 2024-03-21  47207.84  47607.23  46968.38  47514.30  Auto.csv
# 2488 2024-03-22  47552.96  48537.47  47291.61  48249.98  Auto.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2487        0.020388          0.189922            0.274425       0.611175
# 2488        0.017356          0.191999            0.314899       0.650096
#
#       Composite Score
# 2487         0.293587
# 2488         0.293587
#            Date    Open    High     Low   Close               dummy  \
# 2430 2024-03-21  540.84  550.96  540.59  550.31  infrastructure.csv
# 2431 2024-03-22  549.60  557.30  545.92  554.69  infrastructure.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2430       -0.024048          0.190812            0.452120       1.008137
# 2431       -0.030347          0.193806            0.475553       1.004227
#
#       Composite Score
# 2430          0.41081
# 2431          0.41081
#            Date     Open     High      Low    Close         dummy  \
# 2050 2024-03-21  1830.49  1860.53  1830.31  1857.69  momentum.csv
# 2051 2024-03-22  1854.47  1883.52  1847.48  1876.88  momentum.csv
#
#       Monthly Return  Quarterly Return  Half-Yearly Return  Annual Return  \
# 2050        0.015203          0.102611            0.297831       0.761027
# 2051        0.010265          0.112779            0.324152       0.783073
#
#       Composite Score
# 2050         0.307567
# 2051         0.307567
# Rank 1: Dataframe from file_smeipo.csv
# Rank 2: Dataframe from file_utilities.csv
# Rank 3: Dataframe from file_reit.csv
# Rank 4: Dataframe from file_realty.csv
# Rank 5: Dataframe from file_infrastructure.csv
# Rank 6: Dataframe from file_cpse.csv
# Rank 7: Dataframe from file_power.csv
# Rank 8: Dataframe from file_PSU.csv
# Rank 9: Dataframe from file_momentum.csv
# Rank 10: Dataframe from file_Auto.csv
# Rank 11: Dataframe from file_oilandgas.csv
# Rank 12: Dataframe from file_energy.csv
# Rank 13: Dataframe from file_capital goods.csv
# Rank 14: Dataframe from file_industrial.csv
# Rank 15: Dataframe from file_services.csv
# Rank 16: Dataframe from file_telecom.csv
# Rank 17: Dataframe from file_healthcare.csv
# Rank 18: Dataframe from file_greenex.csv
# Rank 19: Dataframe from file_consumerdiscretionary.csv
# Rank 20: Dataframe from file_quality.csv
# Rank 21: Dataframe from file_manufacturing.csv
# Rank 22: Dataframe from file_IPO.csv
# Rank 23: Dataframe from file_metal.csv
# Rank 24: Dataframe from file_housing.csv
# Rank 25: Dataframe from file_consumerdurables.csv
# Rank 26: Dataframe from file_carbonex.csv
# Rank 27: Dataframe from file_commodities.csv
# Rank 28: Dataframe from file_TECk.csv
# Rank 29: Dataframe from file_informationtech.csv
# Rank 30: Dataframe from file_finanacialservices.csv
# Rank 31: Dataframe from file_fmcg.csv
# Rank 32: Dataframe from file_bankex.csv
# Rank 33: Dataframe from file_privatebanks.csv
