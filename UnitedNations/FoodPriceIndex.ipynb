# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/UnitedNations/FoodPriceIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.fao.org/worldfoodsituation/foodpricesindex/en/
#Monthly release dates for 2021: 7 January, 4 February, 4 March,
#8 April, 6 May, 3 June,8 July, 5 August, 2 September, 7 October,
#4 November, 2 December.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
foodprice=pd.read_csv('https://raw.githubusercontent.com/anirbanghoshsbi/data/main/Food_price_indices_data_nov815.csv',header=[2],index_col=[0])

# %%
foodprice.tail(2)
# Out:
#          Food Price Index   Meat  Dairy  Cereals    Oils  Sugar
# Date
# 2021-09             129.2  112.8  118.1    132.8  168.57  121.2
# 2021-10             133.2  112.1  120.7    137.1  184.84  119.1

# %%
foodprice.plot(figsize=(10,5));

# %%
foodprice['Food Price Index'].plot(figsize=(10,5));
plt.title('Food Prices Index');

# %%
foodprice['Oils'].plot(figsize=(10,5));
plt.title('Oil Prices');

# %%
foodprice['Sugar'].plot(figsize=(10,5));
plt.title('Sugar Prices');

# %%
foodprice['Cereals'].plot(figsize=(10,5));
plt.title('Cereals Prices');

# %%
foodprice['Dairy'].plot(figsize=(10,5));
plt.title('Dairy Prices');

# %%
foodprice['Meat'].plot(figsize=(10,5));
plt.title('Meat Prices');
