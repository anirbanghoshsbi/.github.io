# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/instrumentlist" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data_link = 'https://raw.githubusercontent.com/anirbanghoshsbi/data/main/instruments.csv'

# %%
data=pd.read_csv(data_link)

# %%
data.head(2)
# Out:
#    Unnamed: 0  instrument_token  ...  segment exchange
# 0           0         272376070  ...  BCD-FUT      BCD
# 1           1         272086278  ...  BCD-FUT      BCD
#
# [2 rows x 13 columns]

# %%
data.segment.unique()
# Out:
# array(['BCD-FUT', 'BCD', 'BCD-OPT', 'BSE', 'INDICES', 'CDS-FUT',
#        'CDS-OPT', 'MCX-FUT', 'MCX-OPT', 'NFO-OPT', 'NFO-FUT', 'NSE'],
#       dtype=object)

# %%
for item in data.name.unique():
  if str(item).startswith('NIFTY'):
    print(item)

# %%
filtered_value=np.where((data['name'].str.contains('NIFTY'))&(data.segment=="NSE"))

# %%
data.loc[filtered_value]
# Out:
#         Unnamed: 0  instrument_token  ...  segment exchange
# 99487        99487           5440513  ...      NSE      NSE
# 99794        99794           2976001  ...      NSE      NSE
# 100210      100210           2543873  ...      NSE      NSE
# 100281      100281           7780353  ...      NSE      NSE
# 100282      100282           7565569  ...      NSE      NSE
# 100302      100302           4808449  ...      NSE      NSE
# 100465      100465           6199553  ...      NSE      NSE
# 100592      100592           4634113  ...      NSE      NSE
# 100885      100885           7571713  ...      NSE      NSE
# 100932      100932           2707457  ...      NSE      NSE
# 101146      101146           4305665  ...      NSE      NSE
# 101321      101321           2605057  ...      NSE      NSE
# 101322      101322           1884417  ...      NSE      NSE
# 101323      101323           1882369  ...      NSE      NSE
#
# [14 rows x 13 columns]

# %%
filtered_value=np.where((data['name'].str.contains('BANK'))&(data.segment=="NSE"))

# %%
data.loc[filtered_value]
# Out:
#         Unnamed: 0  instrument_token  ...  segment exchange
# 99465        99465           5436929  ...      NSE      NSE
# 99480        99480           1510401  ...      NSE      NSE
# 99511        99511            579329  ...      NSE      NSE
# 99513        99513            210433  ...      NSE      NSE
# 99514        99514           1195009  ...      NSE      NSE
# 99515        99515           2928385  ...      NSE      NSE
# 99516        99516           1214721  ...      NSE      NSE
# 99611        99611           2763265  ...      NSE      NSE
# 99632        99632           3812865  ...      NSE      NSE
# 99689        99689           3831297  ...      NSE      NSE
# 99691        99691           1459457  ...      NSE      NSE
# 99710        99710           3513601  ...      NSE      NSE
# 99733        99733           2907905  ...      NSE      NSE
# 99794        99794           2976001  ...      NSE      NSE
# 99869        99869            261889  ...      NSE      NSE
# ...
