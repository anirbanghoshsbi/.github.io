# %% [markdown]
# <a href="https://colab.research.google.com/github/anirbanghoshsbi/.github.io/blob/master/GENAI/Fine_Tuning_LLMs_using_LlaMA_Factory_WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# %rm -rf LLaMA-Factory
# !git clone https://github.com/hiyouga/LLaMA-Factory.git
# %cd LLaMA-Factory
# %ls
# %pip install -e .[torch,bitsandbytes]
# Out:
# /content
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 16155, done.
# remote: Counting objects: 100% (6973/6973), done.
# remote: Compressing objects: 100% (380/380), done.
# remote: Total 16155 (delta 6638), reused 6651 (delta 6590), pack-reused 9182
# Receiving objects: 100% (16155/16155), 222.75 MiB | 13.29 MiB/s, done.
# Resolving deltas: 100% (12010/12010), done.
# /content/LLaMA-Factory
# assets/       docker/      LICENSE      pyproject.toml  requirements.txt  src/
# CITATION.cff  evaluation/  Makefile     README.md       scripts/          tests/
# data/         examples/    MANIFEST.in  README_zh.md    setup.py
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 5.7 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login
from google.colab import userdata
hf_token = userdata.get("HUGGINGFACE_TOKEN")
login(token = hf_token)

# %%
# %cd /content/LLaMA-Factory/
# !GRADIO_SHARE=1 llamafactory-cli webui
# Out:
# /content/LLaMA-Factory
# 2024-08-11 14:00:13.723844: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-11 14:00:14.045257: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-11 14:00:14.129466: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-11 14:00:14.632845: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
